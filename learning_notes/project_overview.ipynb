# %% [markdown]
# # 🏗️ Architecture Overview
#
# #### Workflow:
#
# Raw Data (E-commerce dataset)
#
#        ↓
#
#  BigQuery (data warehouse)
#
#        ↓
#
#  dbt (data transformation, cleaning, testing)
#
#        ↓
#
#  Transformed Tables (facts, dimensions, marts)
#
#        ↓
#
#  Dashboard (Looker Studio / Metabase)
#
#
# And behind the scenes, you’ll also add:
#
# CI/CD pipelines → automate builds & testing
#
# Documentation → dbt’s auto-generated data docs
#
# Orchestration → run the pipeline on a schedule (e.g., daily)
#
# Version control → GitHub repo managing your code and configs

# %% [markdown]
# # 🎯 1. Core Data Engineering Concepts
#
# #### Building data pipelines (extract → transform → load)
#
# #### Understanding data modeling layers: raw → staging → fact/dimension → marts
#
# #### Handling incremental data, updates, and slowly changing dimensions (SCDs)
#
# #### Writing SQL for analytics, optimized for warehouses
#
# # 🧮 2. Analytics Engineering (dbt-focused)
#
# #### Building modular SQL models using dbt
#
# #### Using dbt tests, snapshots, macros, and docs
#
# #### Implementing data quality checks and validation
#
# #### Understanding lineage — seeing how data flows end-to-end
#
# # ⚙️ 3. BigQuery & Cloud Skills
#
# #### Designing partitioned and clustered tables
#
# #### Managing datasets, permissions, and service accounts
#
# #### Query optimization and cost management
#
# #### Connecting BigQuery with external tools (dashboards, scripts)
#
# # 🤖 4. Automation & DevOps Practices
#
# #### Using Git + GitHub for version control
#
# #### Setting up CI/CD to run dbt automatically on push
#
# #### Scheduling dbt jobs with GitHub Actions or Cloud Composer (Airflow)
#
# #### Managing credentials and secrets securely
